# %%
from tensorflow.keras.layers import (
    Input,Conv2D,LeakyReLU,Flatten,Dense,Reshape,Conv2DTranspose,Activation,BatchNormalization,
    Dropout,UpSampling2D,MaxPooling2D
)
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import normalize
from tensorflow.keras import backend as K
from tensorflow.keras import mixed_precision
# random weight init
from tensorflow.keras.initializers import RandomNormal
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# Out:
# 2023-07-10 21:02:50.100449: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
class WGAN:
    def __init__(
        self,
        input_dim,
        discriminator_conv_filters,
        discriminator_conv_kernel_size,
        discriminator_conv_strides,
        discriminator_pool_kernel_size,
        discriminator_batch_norm_momentum,
        discriminator_activation,
        discriminator_dropout_rate,
        discriminator_learning_rate,
        discriminator_training_loops,
        generator_initial_dense_layer_size,
        generator_upsample,
        generator_conv_filters,
        generator_conv_kernel_size,
        generator_conv_strides,
        generator_batch_norm_momentum,
        generator_activation,
        generator_dropout_rate,
        generator_learning_rate,
        optimiser,
        z_dim,
        clip_value,
    ):
        self.name = 'wgan'
        self.input_dim = input_dim
        self.discriminator_conv_filters = discriminator_conv_filters
        self.discriminator_conv_kernel_size = discriminator_conv_kernel_size
        self.discriminator_conv_strides = discriminator_conv_strides
        self.discriminator_pool_kernel_size = discriminator_pool_kernel_size
        self.discriminator_batch_norm_momentum = discriminator_batch_norm_momentum
        self.discriminator_activation = discriminator_activation
        self.discriminator_dropout_rate = discriminator_dropout_rate
        self.discriminator_learning_rate = discriminator_learning_rate
        self.discriminator_training_loops = discriminator_training_loops
        self.generator_initial_dense_layer_size = generator_initial_dense_layer_size
        self.generator_upsample = generator_upsample
        self.generator_conv_filters = generator_conv_filters
        self.generator_conv_kernel_size = generator_conv_kernel_size
        self.generator_conv_strides = generator_conv_strides
        self.generator_batch_norm_momentum = generator_batch_norm_momentum
        self.generator_activation = generator_activation
        self.generator_dropout_rate = generator_dropout_rate
        self.generator_learning_rate = generator_learning_rate
        self.optimiser = optimiser
        self.z_dim = z_dim
        self.n_layers_discriminator = len(discriminator_conv_filters)
        self.n_layers_generator = len(generator_conv_filters)
        self.weight_init = RandomNormal(mean=0., stddev=0.02)
        self.clip_value = clip_value
        self.build_discriminator()
        self.build_generator()
        self.build_combined()
    # 定义瓦式损失函数
    def wasserstein(self, y_true, y_pred):
        return -K.mean(y_true * y_pred)
    # 定义生成器构建函数
    def build_discriminator(self):

        ### THE discriminator
        discriminator_input = Input(shape=self.input_dim, name='discriminator_input')

        x = discriminator_input

        for i in range(self.n_layers_discriminator):

            x = Conv2D(
                filters = self.discriminator_conv_filters[i]
                , kernel_size = self.discriminator_conv_kernel_size[i]
                , strides = self.discriminator_conv_strides[i]
                , padding = 'same'
                , name = 'discriminator_conv_' + str(i)
                , kernel_initializer = self.weight_init
                )(x)

            if self.discriminator_batch_norm_momentum and i > 0:
                x = BatchNormalization(momentum = self.discriminator_batch_norm_momentum)(x)

            x = self.get_activation(self.discriminator_activation)(x)
            if self.discriminator_pool_kernel_size[i] != 0:
                x = MaxPooling2D(self.discriminator_pool_kernel_size[i])(x)
            if self.discriminator_dropout_rate:
                x = Dropout(rate = self.discriminator_dropout_rate)(x)
            
        x = Flatten()(x)
        
        discriminator_output = Dense(1, activation='sigmoid', kernel_initializer = self.weight_init)(x)

        self.discriminator = Model(discriminator_input, discriminator_output)


    def build_generator(self):

        ### THE generat
        generator_input = Input(shape=(self.z_dim,), name='generator_input')

        x = generator_input

        x = Dense(np.prod(self.generator_initial_dense_layer_size), kernel_initializer = self.weight_init)(x)

        if self.generator_batch_norm_momentum:
            x = BatchNormalization(momentum = self.generator_batch_norm_momentum)(x)

        x = self.get_activation(self.generator_activation)(x)

        x = Reshape(self.generator_initial_dense_layer_size)(x)

        if self.generator_dropout_rate:
            x = Dropout(rate = self.generator_dropout_rate)(x)

        for i in range(self.n_layers_generator):

            if self.generator_upsample[i] == 2:
                x = UpSampling2D()(x)
                x = Conv2D(
                    filters = self.generator_conv_filters[i]
                    , kernel_size = self.generator_conv_kernel_size[i]
                    , padding = 'same'
                    , name = 'generator_conv_' + str(i)
                    , kernel_initializer = self.weight_init
                )(x)
            else:

                x = Conv2DTranspose(
                    filters = self.generator_conv_filters[i]
                    , kernel_size = self.generator_conv_kernel_size[i]
                    , padding = 'same'
                    , strides = self.generator_conv_strides[i]
                    , name = 'generator_conv_' + str(i)
                    , kernel_initializer = self.weight_init
                    )(x)

            if i < self.n_layers_generator - 1:

                if self.generator_batch_norm_momentum:
                    x = BatchNormalization(momentum = self.generator_batch_norm_momentum)(x)

                x = self.get_activation(self.generator_activation)(x)


        generator_output = x

        self.generator = Model(generator_input, generator_output)
    # 定义混合模型构建函数
    def build_combined(self):
        # 编译判别器模型
        self.discriminator.compile(
            optimizer=self.optimiser,
            loss=self.wasserstein,
            metrics=['accuracy'],
        )
        # 锁定判别器
        self.discriminator.trainable = False
        # 定义输入层
        combined_input = Input(shape=(self.z_dim,),name='combined_input')
        # 生成器生成数据
        x = self.generator(combined_input)
        # 判别器判别数据
        discriminator_output = self.discriminator(x)
        # 定义混合模型
        self.combined = Model(combined_input,discriminator_output)
        # 编译混合模型
        self.combined.compile(
            optimizer=self.optimiser,
            loss=self.wasserstein,
            metrics=['accuracy'],
        )
    def get_activation(self, activation):
        if activation == 'leaky_relu':
            layer = LeakyReLU(alpha = 0.2)
        else:
            layer = Activation(activation)
        return layer
    # 定义训练器构建函数
    def train_discriminator(self,X_train,BATCH_SIZE):
        # 解锁判别器
        self.discriminator.trainable = True
        # 创建一个全为1的标签
        real = np.ones((BATCH_SIZE,1))
        # 创建一个全为-1的标签
        fake = -np.ones((BATCH_SIZE,1))
        # 从真实数据集中随机抽取一批数据
        idx = np.random.randint(0,X_train.shape[0],BATCH_SIZE)
        real_images = X_train[idx]
        # 从生成器中随机生成一批数据
        noise = np.random.uniform(-1,1,size=(BATCH_SIZE,self.z_dim))
        fake_images = self.generator.predict(noise)
        # 训练判别器
        d_loss_real,d_acc_real = self.discriminator.train_on_batch(real_images,real)
        d_loss_fake,d_acc_fake = self.discriminator.train_on_batch(fake_images,fake)
        d_loss = (d_loss_real + d_loss_fake) / 2
        d_acc = (d_acc_real + d_acc_fake) / 2
        # 权重裁剪
        for l in self.discriminator.layers:
            weights = l.get_weights()
            weights = [np.clip(w,-self.clip_value,self.clip_value) for w in weights]
            l.set_weights(weights)
        return [d_loss,d_acc]
    # 定义训练器构建函数
    def train_generator(self,BATCH_SIZE):
        # 创建一个全为1的标签
        real = np.ones((BATCH_SIZE,1))
        # 从生成器中随机生成一批数据
        noise = np.random.uniform(-1,1,size=(BATCH_SIZE,self.z_dim))
        # 锁定判别器
        self.discriminator.trainable = False
        return self.combined.train_on_batch(noise,real)
    # 定义训练函数
    def train(self,X_train,epochs,BATCH_SIZE):
        with tqdm(total=epochs,unit="epoch") as pbar:
            for epoch in range(epochs):
                # 训练判别器
                for i in range(self.discriminator_training_loops):
                    d_loss,d_acc = self.train_discriminator(X_train,BATCH_SIZE)
                # 训练生成器
                g = self.train_generator(BATCH_SIZE)
                g_loss = g[0]
                g_acc = g[1]
                # 更新进度条
                pbar.set_description("Current Epoch : {}".format(epoch + 1))
                pbar.set_postfix(
                    d_loss = "%.2f" % d_loss,
                    d_acc = "%.2f" % d_acc,
                    g_loss = "%.2f" % g_loss,
                    g_acc = "%.2f" % g_acc
                )
                pbar.update(1)
    # 定义生成函数
    def generate(self,n_samples):
        noise = np.random.uniform(-1,1,size=(n_samples,self.z_dim))
        image = self.generator.predict(noise)
        plt.figure(figsize=(10,10))
        for k in range(n_samples):
            plt.subplot(10,10,k + 1)
            plt.imshow(image[k],cmap='gray')
            plt.axis('off')
        plt.tight_layout()
        plt.show()

# %%
# 加载Minst数据集
(X_train,_),(_,_) = mnist.load_data()
# 将数据集归一化
X_train = normalize(X_train)
# 将数据集转换为4维张量
X_train = np.expand_dims(X_train,axis=3)
X_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
# 实例化模型
gan = WGAN(input_dim = (28,28,1)
        , discriminator_conv_filters = [64,64,128,128]
        , discriminator_conv_kernel_size = [5,5,5,5]
        , discriminator_conv_strides = [1,1,1,1]
        , discriminator_pool_kernel_size=[2,2,2,2]
        , discriminator_batch_norm_momentum = None
        , discriminator_activation = 'leaky_relu'
        , discriminator_dropout_rate = 0.4
        , discriminator_learning_rate = 0.0008
        , generator_initial_dense_layer_size = (7, 7, 64)
        , generator_upsample = [2,2, 1, 1]
        , generator_conv_filters = [128,64, 64,1]
        , generator_conv_kernel_size = [5,5,5,5]
        , generator_conv_strides = [1,1, 1, 1]
        , generator_batch_norm_momentum = 0.9
        , generator_activation = 'leaky_relu'
        , generator_dropout_rate = None
        , generator_learning_rate = 0.0004
        , optimiser = 'adam'
        , z_dim = 100
        , discriminator_training_loops=3,
        clip_value=0.01
        )

# %%
# 训练模型
gan.train(X_train,epochs=3000,BATCH_SIZE=32)
# Out:
# ...
# 1/1 [==============================] - 0s 105ms/step
# 2023-07-10 21:12:14.300218: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_9/dropout_12/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# ...
# 1/1 [==============================] - 0s 16ms/step
# 2023-07-10 21:12:16.863572: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_11/model_9/dropout_12/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# ...
# 1/1 [==============================] - 0s 17ms/step
# ...
# ...
# 1/1 [==============================] - 0s 17ms/step

# %%
# 生成数据
gan.generate(5)
# Out:
# 1/1 [==============================] - 0s 19ms/step
